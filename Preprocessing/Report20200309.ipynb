# %%
import numpy as np
import pandas as pd
import heartpy as hp
import matplotlib.pyplot as plt
import scipy.io as sio

# %%
RawData1 = sio.loadmat( 'C:/4th_2endSemester/MLBRLab/BPEstimation/data/Part_1.mat' )

# %% [markdown]
# #Case Study
# #Patient Number 0

# %%
Fs = 125 
Ts = 1/125
N = len(RawData1['Part_1'][0][0][1][0:999])
t = np.linspace( 0 , N , N )
F = t*Fs/N - Fs/2

#plt.plot( t , RawData1['Part_1'][0][0][1][0:999] )

yf = np.fft.fft( RawData1['Part_1'][0][0][1][0:999] )
yf = np.fft.fftshift(yf)
Y = np.abs( a/N )
        
plt.plot( F , Y ) 
plt.show()

yf4 = yf
for i in range(N):
    if ( F[i] > 4 ) | ( F[i] <-4 ):
        yf4[i] = 0

plt.plot( t , RawData1['Part_1'][0][0][1][0:999] )
plt.show()

plt.plot( t , np.abs( np.fft.ifft( yf4 ) ) )
plt.show()


yf6 = yf
for i in range(N):
    if ( F[i] > 6 ) | ( F[i] <-6 ):
        yf6[i] = 0
plt.plot( t , np.abs( np.fft.ifft( yf6 ) ) )
plt.show()




yf10 = yf
for i in range(N):
    if ( F[i] > 40 ) | ( F[i] < -40 ):
        yf10[i] = 0
plt.plot( t , np.abs( np.fft.ifft( yf8 ) ) )
plt.show()

# %% [markdown]
# #Case Study
# #Patient Number 10

# %%
Fs = 125 
Ts = 1/125
N = len(RawData1['Part_1'][0][10][1][0:999])
t = np.linspace( 0 , N , N )
F = t*Fs/N - Fs/2

#plt.plot( t , RawData1['Part_1'][0][0][1][0:999] )

yf = np.fft.fft( RawData1['Part_1'][0][10][1][0:999] )
yf = np.fft.fftshift(yf)
Y = np.abs( a/N )
        
plt.plot( F , Y ) 
plt.show()

yf4 = yf
for i in range(N):
    if ( F[i] > 4 ) | ( F[i] <-4 ):
        yf4[i] = 0

plt.plot( t , RawData1['Part_1'][0][10][1][0:999] )
plt.show()

plt.plot( t , np.abs( np.fft.ifft( yf4 ) ) )
plt.show()


yf6 = yf
for i in range(N):
    if ( F[i] > 6 ) | ( F[i] <-6 ):
        yf6[i] = 0
plt.plot( t , np.abs( np.fft.ifft( yf6 ) ) )
plt.show()




yf8 = yf
for i in range(N):
    if ( F[i] > 8 ) | ( F[i] < -8 ):
        yf10[i] = 0
plt.plot( t , np.abs( np.fft.ifft( yf8 ) ) )
plt.show()


yf10 = yf
for i in range(N):
    if ( F[i] > 10 ) | ( F[i] < -10 ):
        yf10[i] = 0
plt.plot( t , np.abs( np.fft.ifft( yf10 ) ) )
plt.show()

# %% [markdown]
# #Case Study
# #Patient Number 13

# %%
Fs = 125 
Ts = 1/125
N = len(RawData1['Part_1'][0][13][1][0:999])
t = np.linspace( 0 , N , N )
F = t*Fs/N - Fs/2

#plt.plot( t , RawData1['Part_1'][0][0][1][0:999] )

yf = np.fft.fft( RawData1['Part_1'][0][13][1][0:999] )
yf = np.fft.fftshift(yf)
Y = np.abs( a/N )
        
plt.plot( F , Y ) 
plt.show()

yf4 = yf
for i in range(N):
    if ( F[i] > 4 ) | ( F[i] <-4 ):
        yf4[i] = 0

plt.plot( t , RawData1['Part_1'][0][13][1][0:999] )
plt.show()

plt.plot( t , np.abs( np.fft.ifft( yf4 ) ) )
plt.show()


yf6 = yf
for i in range(N):
    if ( F[i] > 6 ) | ( F[i] <-6 ):
        yf6[i] = 0
plt.plot( t , np.abs( np.fft.ifft( yf6 ) ) )
plt.show()




yf8 = yf
for i in range(N):
    if ( F[i] > 8 ) | ( F[i] < -8 ):
        yf10[i] = 0
plt.plot( t , np.abs( np.fft.ifft( yf8 ) ) )
plt.show()


yf10 = yf
for i in range(N):
    if ( F[i] > 10 ) | ( F[i] < -10 ):
        yf10[i] = 0
plt.plot( t , np.abs( np.fft.ifft( yf10 ) ) )
plt.show()
