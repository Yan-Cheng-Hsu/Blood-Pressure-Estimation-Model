# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/Yan-Cheng-Hsu/anaconda3/envs/test/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
RearrangedData = { 'SamplingRate':125.0 , 'ppg' : [] , 'diff1ppg' : [] , 'diff2ppg' : [] , 'abp' : [] }
AttributeTable = { 'systolicIndex': [] , 'systolicValue': [] , 'hr': [] , 'valleyIndex0': [] , 'valleyValue0': [] , 'maxSlopeIndex': [] , 'maxSlopeValue': [] , 'minSlopeIndex' : [] , 'minSlopeValue' : [] , 'peakValue1st': [] , 'valleyValue1st' : [] ,  'DicroticIndex': [] , 'DicroticValue':[] , 'sbp' : [] , 'dbp' : [] , 'peakValue2st' : [] , 'peaIndex2st' : [] , 'valleyValue2st' : [] , 'valleyIndex2st' : [] , 'DicroticDiff2Value' : [] , 'onsetIndex1st' : [] , 'onsetValue1st' : [] , 'onsetIndex2nd' : [] , 'onsetValue2nd' : [] }

# %%
RearrangedData['ppg'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/ppg.npy' , allow_pickle = True )
RearrangedData['abp'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/abp.npy' , allow_pickle = True )
RearrangedData['diff1ppg'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/diff1.npy' , allow_pickle = True )
RearrangedData['diff2ppg'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/diff2.npy' , allow_pickle = True )

# %%
AttributeTable['systolicIndex'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/peakIndex.npy' , allow_pickle = True )
AttributeTable['systolicValue'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/peakValue.npy' , allow_pickle = True )
AttributeTable['valleyIndex0'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/valleyIndex.npy' , allow_pickle = True )
AttributeTable['valleyValue0'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/valleyValue.npy' , allow_pickle = True )
AttributeTable['hr'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/hr.npy' , allow_pickle = True )
AttributeTable['maxSlopeIndex'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/maxSlopeIndex.npy' , allow_pickle = True )
AttributeTable['maxSlopeValue'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/maxSlopeValue.npy' , allow_pickle = True )
AttributeTable['minSlopeIndex'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/minSlopeIndex.npy' , allow_pickle = True ) 
AttributeTable['minSlopeValue'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/minSlopeValue.npy' , allow_pickle = True )
AttributeTable['peakValue1st'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/peakValue1st.npy' , allow_pickle = True )
AttributeTable['valleyValue1st'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/valleyValue1st.npy' , allow_pickle = True ) 
AttributeTable['DicroticIndex'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/DicroticIndex.npy' , allow_pickle = True ) 
AttributeTable['DicroticValue'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/DicroticValue.npy' , allow_pickle = True ) 
AttributeTable['peaIndex2st'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/peaIndex2st.npy' , allow_pickle = True ) 
AttributeTable['peakValue2st'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/peakValue2st.npy' , allow_pickle = True ) 
AttributeTable['valleyIndex2st'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/valleyIndex2st.npy' , allow_pickle = True )
AttributeTable['valleyValue2st'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/valleyValue2st.npy' , allow_pickle = True )
AttributeTable['DicroticDiff2Value'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/DicroticDiff2Value.npy' , allow_pickle = True )
AttributeTable['onsetIndex1st'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/onsetIndex1st.npy' , allow_pickle = True ) 
AttributeTable['onsetValue1st'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/onsetValue1st.npy' , allow_pickle = True ) 
AttributeTable['onsetIndex2nd'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/onsetIndex2nd.npy' , allow_pickle = True ) 
AttributeTable['onsetValue2nd'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/onsetValue2nd.npy' , allow_pickle = True ) 
AttributeTable['sbp'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/sbp.npy' , allow_pickle = True )
AttributeTable['dbp'] = np.load( '/data1/Yan-Cheng-Hsu/ppgData/f8_normalizedppg/dbp.npy' , allow_pickle = True )

# %%
y = 12
Test = RearrangedData['ppg'][y]
t = np.linspace( 0 , len(Test) , len(Test) )

plt.plot( t , Test , color = 'black' )
plt.plot( AttributeTable['systolicIndex'][y] , AttributeTable['systolicValue'][y]  , 'o' , color = 'red' )
plt.plot( AttributeTable['valleyIndex0'][y] , AttributeTable['valleyValue0'][y]  , 'o' , color = 'blue' )
plt.plot( AttributeTable['DicroticIndex'][y] , AttributeTable['DicroticValue'][y] , 'o' , color = 'purple' )
plt.plot( AttributeTable['maxSlopeIndex'][y] , AttributeTable['maxSlopeValue'][y] , '*' , color = 'green' )
plt.plot( AttributeTable['minSlopeIndex'][y] , AttributeTable['minSlopeValue'][y] , '*' , color = 'brown' )
#plt.plot( AttributeTable['DiastolicIndex'][y] , AttributeTable['DiastolicValue'][y] , 'D' , color = 'yellow' )


plt.legend( loc = 'best' )
plt.show()


Test1 = RearrangedData['diff1ppg'][y]
t1 = np.linspace( 0 , len(Test1) , len(Test1) )

plt.plot( t1 , Test1 , color = 'black' )
plt.plot( AttributeTable['maxSlopeIndex'][y] , AttributeTable['peakValue1st'][y] , 'o' )
plt.plot( AttributeTable['minSlopeIndex'][y] , AttributeTable['valleyValue1st'][y] , 'o' )
plt.plot( AttributeTable['onsetIndex1st'][y] , AttributeTable['onsetValue1st'][y] , 'D' , color = 'blue' )
plt.show()


Test2 = RearrangedData['diff2ppg'][y]
t2 = np.linspace( 0 , len(Test2) , len(Test2) )

plt.plot( t2 , Test2 , color = 'black' )
plt.plot( AttributeTable['peaIndex2st'][y] , AttributeTable['peakValue2st'][y] , 'o' )
plt.plot( AttributeTable['valleyIndex2st'][y] , AttributeTable['valleyValue2st'][y] , 'o' )
plt.plot( AttributeTable['onsetIndex2nd'][y] , AttributeTable['onsetValue2nd'][y] , 'D' , color = 'red' )
#plt.plot( AttributeTable['DicroticIndex'][y] , AttributeTable['DicroticDiff2Value'][y] , 'D' , color = 'blue'  )

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Features = []
BP = []

# %%
for x in range( len(AttributeTable['valleyIndex0']) ):
    featuresofp = []
    bpofp = []

    #extremely abnormal patient
    avghr = np.mean( AttributeTable['hr'][x] )
    if ( avghr > 200 ) or ( avghr < 30 ):
        continue

    for i in range( 2 , len(AttributeTable['valleyIndex0'][x]) - 1 , 1 ):
        temp = []
        bp = []
        avghr = np.mean( AttributeTable['hr'][x] )
        hr = AttributeTable['hr'][x][i-1]
        sbp = AttributeTable['sbp'][x][i-1]
        dbp = AttributeTable['dbp'][x][i-1]
        pm = sbp - dbp
        DO = AttributeTable['valleyIndex0'][x][i] - AttributeTable['DicroticIndex'][x][i-1]
        #ppg Index
        I1 = AttributeTable['valleyIndex0'][x][i-1]
        I2 = AttributeTable['maxSlopeIndex'][x][i-1]
        I3 = AttributeTable['systolicIndex'][x][i]
        I4 = AttributeTable['DicroticIndex'][x][i-1]
        I5 = AttributeTable['valleyIndex0'][x][i]
        #diff1 Index
        I6  = AttributeTable['onsetIndex1st'][x][i-2]
        I7 = AttributeTable['maxSlopeIndex'][x][i-1]
        I8 = AttributeTable['minSlopeIndex'][x][i-1]
        I9 = AttributeTable['onsetIndex1st'][x][i-1]
        #diff2 Index
        I10 = AttributeTable['onsetIndex2nd'][x][i-2]
        I11 = AttributeTable['peaIndex2st'][x][i-1]
        I12 = AttributeTable['valleyIndex2st'][x][i-1]
        I13 = AttributeTable['onsetIndex2nd'][x][i-1]
        DA = np.sum( RearrangedData['ppg'][x][I3:I5+1] )
        dDA = np.sum( RearrangedData['diff1ppg'][x][I7:I8+1] ) 
        sdDA = np.sum( RearrangedData['diff2ppg'][x][I11:I12+1] )
        
        a1 = I2 - I1
        a2 = I3 - I2
        a3 = I4 - I3
        a4 = I5 - I4
        a5 = I7 - I6
        a6 = I8 - I7
        a7 = I11 - I10
        a8 = I12 - I11
        a9 = a1 + a2
        a10 = a3 + a4
        a11 = I13 - I12
        a12 = I9 - I8
        a13 = DA
        a14 = dDA
        a15 = sdDA
        a16 = AttributeTable['valleyValue0'][x][i-1]
        a17 = AttributeTable['onsetValue1st'][x][i-2]
        a18 = AttributeTable['onsetValue2nd'][x][i-2]
        a19 = AttributeTable['valleyValue1st'][x][i-1]
        a20 = AttributeTable['valleyValue2st'][x][i-1]
        a21 = np.sum( RearrangedData['ppg'][x][I4:I5+1] )
        a22 = AttributeTable['systolicValue'][x][i]
        

        if ( hr > (1.3*avghr) ) or ( hr < (avghr/1.3) ) or ( hr > 200 ) or ( hr < 20 ) or ( sbp > 240 ) or ( dbp < 20 ) or ( pm < 30 ) or ( pm > 150 ) :# or ( DO < 5 ): 
            temp = np.zeros( 59 )
            bp = np.zeros( 2 )
            featuresofp.append( temp )
            bpofp.append( bp )
            continue
        
        if ( a1 == 0 ) or ( a2 == 0 ) or ( a3 == 0 ) or ( a4 == 0 ) or ( a5 == 0 ) or ( a6 == 0 ) or ( a7 == 0 ) or ( a8 == 0 ) or ( a9 == 0 ) or ( a10 == 0 ) :
            temp = np.zeros( 59 )
            bp = np.zeros( 2 )
            featuresofp.append( temp )
            bpofp.append( bp )
            continue
        if ( a11 == 0 ) or ( a12 == 0 ) or ( a13 == 0 ) or ( a14 == 0 ) or ( a15 == 0 ) or ( a16 == 0 ) or ( a17 == 0 ) or ( a18 == 0 ) or ( a19 == 0 ) or ( a20 == 0 ) :
            temp = np.zeros( 59 )
            bp = np.zeros( 2 )
            featuresofp.append( temp )
            bpofp.append( bp )
            continue
        if ( a21 == 0 ) or ( a22 == 0 ) :
            temp = np.zeros( 59 )
            bp = np.zeros( 2 )
            featuresofp.append( temp )
            bpofp.append( bp )
            continue

        t1 = 125*60 / ( I2 - I1 )
        t2 = 125*60 / ( I3 - I2 )
        t3 = 125*60 / ( I4 - I3 )
        t4 = 125*60 / ( I5 - I4 )
        t5 = 125*60 / ( I7 - I6 )
        t6 = 125*60 / ( I8 - I7 )
        t7 = 125*60 / ( I11 - I10 )
        t8 = 125*60 / ( I12 - I11 )



        #Dicrotic-Notch-Free and TPR related Features 
        #Ascending slope
        AS = ( AttributeTable['systolicValue'][x][i] - AttributeTable['valleyValue0'][x][i-1] ) / ( I3 - I1 )
        dAS = ( AttributeTable['maxSlopeValue'][x][i-1] - AttributeTable['onsetValue1st'][x][i-2] ) / ( I7 - I6 )
        sdAS = ( AttributeTable['peakValue2st'][x][i-1] - AttributeTable['onsetValue2nd'][x][i-2] ) / ( I11 - I10 )
        #Dscending slope
        DS = ( AttributeTable['valleyValue0'][x][i] - AttributeTable['systolicValue'][x][i] ) / ( I5 - I3 )
        dDS = ( AttributeTable['valleyValue1st'][x][i-1] - AttributeTable['peakValue1st'][x][i-1] ) - ( I8 - I7 )
        sdDS = ( AttributeTable['valleyValue2st'][x][i-1] - AttributeTable['peakValue2st'][x][i-1] ) / ( I12 - I11 )
        #Area Indices
        S1 = np.sum( RearrangedData['ppg'][x][I1:I2+1] )
        S2 = np.sum( RearrangedData['ppg'][x][I2:I3+1] )
        #Ascending area
        AA = np.sum( RearrangedData['ppg'][x][I1:I3+1] )
        dAA = np.sum( RearrangedData['diff1ppg'][x][I6:I7+1] )
        sdAA = np.sum( RearrangedData['diff2ppg'][x][I10:I11+1] )
        
        
        
        
        #Descending area
        DA = np.sum( RearrangedData['ppg'][x][I3:I5+1] )
        dDA = np.sum( RearrangedData['diff1ppg'][x][I7:I8+1] ) 
        sdDA = np.sum( RearrangedData['diff2ppg'][x][I11:I12+1] )
        #Area relative Indices
        RAAD = AA / DA
        dRAAD = dAA / dDA
        sdRAAD = sdAA / sdAA
        #Peak intesity
        PI = AttributeTable['systolicValue'][x][i]
        dPI = AttributeTable['peakValue1st'][x][i-1]
        sdPI = AttributeTable['peakValue2st'][x][i-2]
        #Valley intensity
        dVI = AttributeTable['valleyValue1st'][x][i-1]
        sdVI = AttributeTable['valleyValue2st'][x][i-1]
        
        
        
        
        #Intensity difference indices
        #Ascending Intensity difference
        AID = PI - AttributeTable['valleyValue0'][x][i-1]
        dAID = AttributeTable['peakValue1st'][x][i-1] - AttributeTable['onsetValue1st'][x][i-2]
        sdAID = AttributeTable['peakValue2st'][x][i-1] - AttributeTable['onsetValue2nd'][x][i-2]
        #Dscending Intensity difference
        dDID = AttributeTable['peakValue1st'][x][i-1] - AttributeTable['valleyValue1st'][x][i-1]
        sdDID = AttributeTable['peakValue2st'][x][i-1] - AttributeTable['valleyValue2st'][x][i-1]
        #PIR 
        PIR = AttributeTable['systolicValue'][x][i] / AttributeTable['valleyValue0'][x][i-1]
        dPIR = AttributeTable['peakValue1st'][x][i-1] / AttributeTable['onsetValue1st'][x][i-2]
        sdPIR = AttributeTable['peakValue2st'][x][i-1] / AttributeTable['onsetValue2nd'][x][i-2]
        #RIPV
        dRIPV = AttributeTable['peakValue1st'][x][i-1] / AttributeTable['valleyValue1st'][x][i-1]
        sdRIPV = AttributeTable['peakValue2st'][x][i-1] / AttributeTable['valleyValue2st'][x][i-1]
        
        
        
        
        #Time space indice
        #Ascending intensity difference
        AT = 125*60 / ( I3 - I1 )
        dAT = 125*60 / ( I7 - I6 )##########
        sdAT = 125*60 / ( I11 - I10)############
        #Descending intensity difference
        DT = 125*60 / ( I5 - I3 )
        dDT = 125*60 / ( I8 - I7 )
        sdDT = 125*60 / ( I12 - I11 )
        dTVO = 125*60 / ( I9 - I8 )
        sdTVO = 125*60 / ( I13 - I12 )


        #Dicrotic Notich Related Features
        Slope_a = ( AttributeTable['DicroticValue'][x][i-1] - AttributeTable['systolicValue'][x][i] ) / ( I4 - I3 )
        S3 = np.sum( RearrangedData['ppg'][x][I3:I4+1] )
        S4 = np.sum( RearrangedData['ppg'][x][I4:I5+1] )
        RtArea = ( S1 + S2 + S3 ) / S4
        NI = AttributeTable['DicroticValue'][x][i-1]
        AI = NI / PI
        AI1 = ( PI - NI ) / PI
        RSD = ( t1 + t2 + t3 ) / t4
        RSC = ( t1 + t2 + t3 ) / hr 
        RDC = t4 / hr



        temp.append( hr )
        temp.append( t1 )
        temp.append( t2 )
        temp.append( t3 )
        temp.append( t4 )
        temp.append( t5 )
        temp.append( t6 )
        temp.append( t7 )
        temp.append( t8 )
        temp.append( AS )
        temp.append( dAS )
        temp.append( sdAS )
        temp.append( DS )
        temp.append( dDS )
        temp.append( sdDS )
        temp.append( S1 )
        temp.append( S2 )
        temp.append( AA )
        temp.append( dAA )
        temp.append( sdAA )
        temp.append( DA )
        temp.append( dDA )
        temp.append( sdDA )
        temp.append( RAAD )
        temp.append( dRAAD )
        temp.append( sdRAAD )
        temp.append( PI )
        temp.append( dPI )
        temp.append( sdPI )
        temp.append( dVI )
        temp.append( sdVI )
        temp.append( AID )
        temp.append( dAID )
        temp.append( sdAID )
        temp.append( dDID )
        temp.append( sdDID )
        temp.append( PIR )
        temp.append( dPIR )
        temp.append( sdPIR )
        temp.append( dRIPV )
        temp.append( sdRIPV )
        temp.append( AT )
        temp.append( dAT )
        temp.append( sdAT )
        temp.append( DT )
        temp.append( dDT )
        temp.append( sdDT )
        temp.append( dTVO )
        temp.append( sdTVO )
        temp.append( Slope_a )
        temp.append( S3 )
        temp.append( S4 )
        temp.append( RtArea )
        temp.append( NI )
        temp.append( AI )
        temp.append( AI1 )
        temp.append( RSD )
        temp.append( RSC )
        temp.append( RDC )

        temp = np.array( temp )
        bp.append( sbp )
        bp.append( dbp )
        bp = np.array( bp )
        featuresofp.append( temp )
        bpofp.append( bp )
    
    if ( len(featuresofp) != 0 ) and ( len(bpofp) != 0 ):
        featuresofp = np.array( featuresofp )
        bpofp = np.array( bpofp )

        Features.append( featuresofp )
        BP.append( bpofp )
# Out:
# /home/Yan-Cheng-Hsu/anaconda3/envs/test/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/Yan-Cheng-Hsu/anaconda3/envs/test/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
BP = np.array( BP )
Features = np.array( Features )

# %%
L = [ 'hr' , 't1' , 't2' ,'t3' , 't4' , 't5' , 't6' , 't7' , 't8' , 
       'AS' , 'dAS' , 'sdAS' ,  'DS' , 'dDS' , 'sdDS' ,   'S1' , 'S2' , 
       'AA' , 'dAA' , 'sdAA' , 'DA' , 'dDA' , 'sdDA' ,
       'RAAD' , 'dRAAD' , 'sdRAAD' , 'PI' , 'dPI' , 'sdPI' , 'dVI', 'sdVI',
       'AID' , 'dAID', 'sdAID' , 'dDID' , 'sdDID' , 'PIR' , 'dPIR' , 'sdPIR' , 
       'dRIPV' , 'sdRIPV' ,'AT', 'dAT' , 'sdAT' , 'DT' , 'dDT' , 'sdDT' , 'dTVO' , 'sdTVO',
       'Slope_a' , 'S3' , 'S4' , 'RtArea' , 'NI', 'AI' , 'AI1' , 'RSD' , 'RSC' , 'RDC' , 'ni' ]
Att = {}

# %%
for index in range( len(Features[0][0]) + 1  ):
    if index != 59:
        Att[ L[index] ] = []
        for i in range( len(Features) ):
            for j in range( len(Features[i]) ):
                if Features[i][j][index] != 0:
                    Att[ L[index] ].append( Features[i][j][index] )
        Att[ L[index] ] = np.array( Att[ L[index] ] ) 
    else:
        Att[ L[index] ] = []
        for i in range( len(Features) ):
            for j in range( len(Features[i]) ):
                if Features[i][j][53] != 0:
                    Att[ L[index] ].append( Features[i][j][53] )
        Att[ L[index] ] = np.array( Att[ L[index] ] ) 
        
        
for i in L:
    if i != 'ni':
        Att[ i ] = ( Att[ i ] - np.mean( Att[ i ] ) ) / np.std( Att[ i ] )
        Att[ i ] = np.round( Att[ i ] , 1 )
        Att[ i ] = np.sort( Att[ i ] , kind = 'heapsort' )
    else:
        Att[ i ] = np.sort( Att[ i ] , kind = 'heapsort' )
# Out:
# /home/Yan-Cheng-Hsu/anaconda3/envs/test/lib/python3.6/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in true_divide

# %%
import math
x = {}
y = {}
g = {}
for index in L:
    if index == 'ni':
        continue
    else:
        x[ index ] = []
        y[ index ] = []
        x[ index ].append( Att[ index ][0] )
        y[ index ].append( 1 )
        j = 0
        for i in range( 1 , len(Att[ index ]) , 1 ):
            if Att[ index ][i] == x[ index ][j]:
                y[ index ][j] = y[ index ][j] + 1
            else:
                x[ index ].append( Att[ index ][i] )
                y[ index ].append( 1 )
                j = j + 1

# %%
import math
import pandas as pd
from scipy.stats import norm
for i in L:
    if i == 'PIR' or i == 'RAAD' or i == 'dRAAD' or i == 'sdRAAD' or i == 'ni':
        continue
    else:
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        print( i , ':' )
        print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'black' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 )#label = 'normal distribution' )
        plt.xticks( x[i][0::50] )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.show()
# Out:
# hr :
# max MAE =  0.016355450799264776
# MAE =  0.0128115720576161
# t1 :
# max MAE =  0.016355450799264776
# MAE =  0.02121918995915813
# t2 :
# max MAE =  0.016355450799264776
# MAE =  0.016530541630985628
# t3 :
# max MAE =  0.016355450799264776
# MAE =  0.01637178238664169
# t4 :
# max MAE =  0.016355450799264776
# MAE =  0.016040427777297615
# t5 :
# max MAE =  0.016355450799264776
# MAE =  0.01634654472217917
# t6 :
# max MAE =  0.016355450799264776
# MAE =  0.016288353634904808
# t7 :
# max MAE =  0.016355450799264776
# MAE =  0.016737830584281004
# t8 :
# max MAE =  0.016355450799264776
# MAE =  0.01628400376845084
# AS :
# max MAE =  0.016355450799264776
# MAE =  0.012769872429417737
# dAS :
# max MAE =  0.016355450799264776
# MAE =  0.014554384994831786
# sdAS :
# max MAE =  0.016355450799264776
# MAE =  0.014052564634453188
# DS :
# max MAE =  0.016355450799264776
# MAE =  0.014055100491763596
# dDS :
# max MAE =  0.016355450799264776
# MAE =  0.016467088804870526
# ...

# %%
for i in L:
    if i == 'PIR' or i == 'RAAD' or i == 'dRAAD' or i == 'sdRAAD' or i == 'ni':
        continue
    else:
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        print( i , ':' )
        print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'blue' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 )#label = 'normal distribution' )
        plt.xticks( x[i][0::50] )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.show()
# Out:
# hr :
# max MAE =  0.016355450799264776
# MAE =  0.0128115720576161
# t1 :
# max MAE =  0.016355450799264776
# MAE =  0.02121918995915813
# t2 :
# max MAE =  0.016355450799264776
# MAE =  0.016530541630985628
# t3 :
# max MAE =  0.016355450799264776
# MAE =  0.01637178238664169
# t4 :
# max MAE =  0.016355450799264776
# MAE =  0.016040427777297615
# t5 :
# max MAE =  0.016355450799264776
# MAE =  0.01634654472217917
# t6 :
# max MAE =  0.016355450799264776
# MAE =  0.016288353634904808
# t7 :
# max MAE =  0.016355450799264776
# MAE =  0.016737830584281004
# t8 :
# max MAE =  0.016355450799264776
# MAE =  0.01628400376845084
# AS :
# max MAE =  0.016355450799264776
# MAE =  0.012769872429417737
# dAS :
# max MAE =  0.016355450799264776
# MAE =  0.014554384994831786
# sdAS :
# max MAE =  0.016355450799264776
# MAE =  0.014052564634453188
# DS :
# max MAE =  0.016355450799264776
# MAE =  0.014055100491763596
# dDS :
# max MAE =  0.016355450799264776
# MAE =  0.016467088804870526
# ...

# %%
T = [ 'dDA' , 'NI' ]

for i in T:
    if i == 'NI' :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 211 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'black' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Notch Intensity (NI) Distribution ' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.05) )
        plt.legend( loc = 'upper left' )
        plt.show()
    else :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 212 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'black' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Descending Area (DA) Distribution ' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.05) )
        plt.legend( loc = 'upper left' )
        plt.show()

# %%
T = [ 'dDA' , 'NI' ]

for i in T:
    if i == 'NI' :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 211 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'blue' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Notch Intensity (NI) Distribution ' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.05) )
        plt.legend( loc = 'upper left' )
        plt.show()
    else :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 212 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'blue' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Descending Area (DA) Distribution ' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.05) )
        plt.legend( loc = 'upper left' )
        plt.show()

# %%
T = [ 'sdAT' , 't7' ]

for i in T:
    if i == 'sdAT' :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 211 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'black' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 ,label = 'normal distribution' )
        #plt.title( 'Histogram of Distribution of Ascending Time Interval'+'\n'+'of 2nd derivative PPG (sdAT)  ' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.4) )
        plt.legend( loc = 'upper left' )
        plt.show()
    else :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 212 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'black' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Descending Time Interval'+ '\n' +'of 1st derivative PPG (dDT)' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.35) )
        plt.legend( loc = 'upper left' )
        plt.show()

# %%
T = [ 'sdAT' , 't7' ]

for i in T:
    if i == 'sdAT' :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 211 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'blue' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 ,label = 'normal distribution' )
        #plt.title( 'Histogram of Distribution of Ascending Time Interval'+'\n'+'of 2nd derivative PPG (sdAT)  ' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.4) )
        plt.legend( loc = 'upper left' )
        plt.show()
    else :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 212 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'blue' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Descending Time Interval'+ '\n' +'of 1st derivative PPG (dDT)' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.35) )
        plt.legend( loc = 'upper left' )
        plt.show()

# %%
T = [ 'sdAS' , 'sdDS' ]

for i in T:
    if i == 'sdAS' :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 211 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'black' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 ,label = 'normal distribution' )
        #plt.title( 'Histogram of Distribution of Ascending Time Interval'+'\n'+'of 2nd derivative PPG (sdAT)  ' )
        plt.xticks( x[i][0::200] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.09) )
        plt.legend( loc = 'upper left' )
        plt.show()
    else :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 212 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'black' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Descending Time Interval'+ '\n' +'of 1st derivative PPG (dDT)' )
        plt.xticks( x[i][0::150] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.06) )
        plt.legend( loc = 'upper left' )
        plt.show()

# %%
T = [ 'sdAS' , 'sdDS' ]

for i in T:
    if i == 'sdAS' :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 211 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'blue' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 ,label = 'normal distribution' )
        #plt.title( 'Histogram of Distribution of Ascending Time Interval'+'\n'+'of 2nd derivative PPG (sdAT)  ' )
        plt.xticks( x[i][0::200] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.09) )
        plt.legend( loc = 'upper left' )
        plt.show()
    else :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 212 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'blue' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Descending Time Interval'+ '\n' +'of 1st derivative PPG (dDT)' )
        plt.xticks( x[i][0::150] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.06) )
        plt.legend( loc = 'upper left' )
        plt.show()

# %%
T = [ 'S1' , 'S2' ]

for i in T:
    if i == 'S2' :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 211 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'black' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 ,label = 'normal distribution' )
        #plt.title( 'Histogram of Distribution of Ascending Time Interval'+'\n'+'of 2nd derivative PPG (sdAT)  ' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.09) )
        plt.legend( loc = 'upper left' )
        plt.show()
    else :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 212 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'black' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Descending Time Interval'+ '\n' +'of 1st derivative PPG (dDT)' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.12) )
        plt.legend( loc = 'upper left' )
        plt.show()

# %%
T = [ 'S1' , 'S2' ]

for i in T:
    if i == 'S2' :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 211 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'blue' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 ,label = 'normal distribution' )
        #plt.title( 'Histogram of Distribution of Ascending Time Interval'+'\n'+'of 2nd derivative PPG (sdAT)  ' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.09) )
        plt.legend( loc = 'upper left' )
        plt.show()
    else :
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        #print( i , ':' )
        #print( 'max MAE = ' , np.mean( np.abs( b ) ) )
        #print( 'MAE = ' , np.mean( np.abs( b-c ) ) )
        #plt.subplot( 212 )
        plt.bar( x[i] , y[i]/np.sum( y[i] ) , color = 'blue' , width = 0.1 , edgecolor = 'white' , lw = 0.2 )#, label = 'error = %f'%(((b-c)**2).mean()**0.5) )
        plt.plot( a , b, color = 'red' , linewidth = 3 , label = 'normal distribution' )
        #plt.title( 'Histogram of Descending Time Interval'+ '\n' +'of 1st derivative PPG (dDT)' )
        plt.xticks( x[i][0::50] )
        #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
        plt.ylabel( 'Probability Density' )
        plt.xlabel( 'Standardized Value (correct to 1 decimal place)' )
        plt.ylim( (0,0.12) )
        plt.legend( loc = 'upper left' )
        plt.show()

# %%
x['ni'] = [i for i in range( 0 , 101 ,1)]
x['ni'] = np.array( x['ni'] ) / 100
Att['ni'] = np.around( Att['ni'] , 2 )
plt.hist(  Att['ni'] , bins = x['ni'] , color = 'black' , width = 0.01 , edgecolor = 'white' , lw = 0.2 ) 
plt.xlabel( ' Normalized Notch Intesity (correct to 2 decimal places) ' )
plt.ylabel( 'Number of Records' )
a = np.linspace( 0 , 1 , 101 )
b = norm.cdf( a+0.01 , loc = np.mean( Att['ni'] ) , scale = np.std( Att['ni'] ) ) - norm.cdf( a , loc = np.mean( Att['ni'] ) , scale = np.std( Att['ni'] ) )
plt.plot( a , b*len(Att['ni']) , color = 'red' , linewidth = 3 , label = 'normal distribution' )
plt.legend( loc = 'upper left' )
plt.ylim( (0 , 95000) )
plt.show()

# %%
x['ni'] = [i for i in range( 0 , 101 ,1)]
x['ni'] = np.array( x['ni'] ) / 100
Att['ni'] = np.around( Att['ni'] , 2 )
plt.hist(  Att['ni'] , bins = x['ni'] , color = 'blue' , width = 0.01 , edgecolor = 'white' , lw = 0.2 ) 
plt.xlabel( ' Normalized Notch Intesity (correct to 2 decimal places) ' )
plt.ylabel( 'Number of Records' )
a = np.linspace( 0 , 1 , 101 )
b = norm.cdf( a+0.01 , loc = np.mean( Att['ni'] ) , scale = np.std( Att['ni'] ) ) - norm.cdf( a , loc = np.mean( Att['ni'] ) , scale = np.std( Att['ni'] ) )
plt.plot( a , b*len(Att['ni']) , color = 'red' , linewidth = 3, label = 'normal distribution' )
plt.legend( loc = 'upper left' )
plt.ylim( (0 , 95000) )
plt.show()

# %%
M = [ 'SBP' , 'DBP' ]
Att1 = {}

# %%
for index in range( len(BP[0][0])  ):
    Att1[ M[index] ] = []
    for i in range( len(BP) ):
        for j in range( len(BP[i]) ):
            if BP[i][j][index] != 0:
                Att1[ M[index] ].append( BP[i][j][index] )
    Att[ M[index] ] = np.array( Att1[ M[index] ] ) 
for i in M:
        Att1[ i ] = np.round( Att1[ i ] , 0 )
        Att1[ i ] = np.sort( Att1[ i ] , kind = 'heapsort' )

# %%
for index in M:
    x[ index ] = []
    y[ index ] = []
    x[ index ].append( Att1[ index ][0] )
    y[ index ].append( 1 )
    j = 0
    for i in range( 1 , len(Att1[ index ]) , 1 ):
        if Att1[ index ][i] == x[ index ][j]:
            y[ index ][j] = y[ index ][j] + 1
        else:
            x[ index ].append( Att1[ index ][i] )
            y[ index ].append( 1 )
            j = j + 1

# %%
for i in M:
    plt.bar( x[i] , y[i] , width = 1 , color = 'black' , edgecolor = 'white' , lw = 0.2 )#,label = 'Mean = '  + str( np.round( np.mean(Att[i]) , 2 ) )+ '\n' + 'Standard of Deviation = ' + str( np.round( np.std(Att[i]) , 2 ) ) + '\n' + 'Max = ' + str(np.around( np.max( Att[i] ) , 2 ) ) + '\n' + 'Min = ' + str(np.around( np.min( Att[i] ) , 2 ) )  )
    #plt.title( 'Histogram of ' + i + ' Distribution ' )
    if i == 'DBP':
        plt.xticks( x[i][0::10] )
    else:
        plt.xticks( x[i][0::20] )
    
    #plt.savefig( '/data1/Yan-Cheng-Hsu/TimeSeriesFeatures/TDFE_20200601/' + i + '.png' )
    
    print( i , ' :' )
    print( 'max = ' , np.max( Att1[i] ) )
    print( 'min = ' , np.min( Att1[i] ) )
    print( 'mean = ' , np.mean( Att1[i] ) )
    print( 'std = ' , np.std( Att1[i] ) )
    
    plt.ylabel( 'Number of records' , color = 'black' )
    if i == 'SBP':
        plt.xlabel( 'Systolic Blood Pressure (mmHg)' , color = 'black' )
    else:
        plt.xlabel( 'Diatolic Blood Pressure (mmHg)' , color = 'black' )

    if i == 'SBP':
        plt.ylim( (0 , 70000) )
    plt.legend( loc = 'upper right' )
    plt.show()
# Out:
# No handles with labels found to put in legend.
# SBP  :
# max =  200.0
# min =  80.0
# mean =  130.99574287528492
# std =  21.773316237879676
# No handles with labels found to put in legend.
# DBP  :
# max =  100.0
# min =  50.0
# mean =  65.96708697421127
# std =  10.099018148339777

# %%
for i in M:
    plt.bar( x[i] , y[i] , width = 1 , color = 'blue' , edgecolor = 'white' , lw = 0.2 )#,label = 'Mean = '  + str( np.round( np.mean(Att[i]) , 2 ) )+ '\n' + 'Standard of Deviation = ' + str( np.round( np.std(Att[i]) , 2 ) ) + '\n' + 'Max = ' + str(np.around( np.max( Att[i] ) , 2 ) ) + '\n' + 'Min = ' + str(np.around( np.min( Att[i] ) , 2 ) )  )
    if i == 'DBP':
        plt.xticks( x[i][0::10] )
    else:
        plt.xticks( x[i][0::20] )
        
    print( i , ' :' )
    print( 'max = ' , np.max( Att1[i] ) )
    print( 'min = ' , np.min( Att1[i] ) )
    print( 'mean = ' , np.mean( Att1[i] ) )
    print( 'std = ' , np.std( Att1[i] ) )
    
    plt.ylabel( 'Number of records' , color = 'black' )
    if i == 'SBP':
        plt.xlabel( 'Systolic Blood Pressure (mmHg)' , color = 'black' )
    else:
        plt.xlabel( 'Diatolic Blood Pressure (mmHg)' , color = 'black' )

    if i == 'SBP':
        plt.ylim( (0 , 70000) )
        
    '''
    if i == 'SBP':
        a = np.linspace( 80 , 200 , 121 )
        b = norm.cdf( a+1 , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) ) - norm.cdf( a , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) )
        plt.plot( a , b*len(Att1[i]) , color = 'red' , linewidth = 3 )    
    else:
        a = np.linspace( 50 , 100 , 51 )
        b = norm.cdf( a+1 , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) ) - norm.cdf( a , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) )
        plt.plot( a , b*len(Att1[i]) , color = 'red' , linewidth = 3 )  
    '''    
        
    plt.show()
# Out:
# SBP  :
# max =  200.0
# min =  80.0
# mean =  130.99574287528492
# std =  21.773316237879676
# DBP  :
# max =  100.0
# min =  50.0
# mean =  65.96708697421127
# std =  10.099018148339777

# %%
for i in M:
    plt.bar( x[i] , y[i] , width = 1 , color = 'black' , edgecolor = 'white' , lw = 0.2 )#,label = 'Mean = '  + str( np.round( np.mean(Att[i]) , 2 ) )+ '\n' + 'Standard of Deviation = ' + str( np.round( np.std(Att[i]) , 2 ) ) + '\n' + 'Max = ' + str(np.around( np.max( Att[i] ) , 2 ) ) + '\n' + 'Min = ' + str(np.around( np.min( Att[i] ) , 2 ) )  )
    if i == 'DBP':
        plt.xticks( x[i][0::10] )
    else:
        plt.xticks( x[i][0::20] )
        
    print( i , ' :' )
    print( 'max = ' , np.max( Att1[i] ) )
    print( 'min = ' , np.min( Att1[i] ) )
    print( 'mean = ' , np.mean( Att1[i] ) )
    print( 'std = ' , np.std( Att1[i] ) )
    
    plt.ylabel( 'Number of records' , color = 'black' )
    if i == 'SBP':
        plt.xlabel( 'Systolic Blood Pressure (mmHg)' , color = 'black' )
    else:
        plt.xlabel( 'Diatolic Blood Pressure (mmHg)' , color = 'black' )

    if i == 'SBP':
        plt.ylim( ( 0 , 70000 ) )
    else: 
        plt.ylim( ( 0 , 150000 ) )
    
    if i == 'SBP':
        startv = int( np.mean( Att1[i] ) - np.std( Att1[i] ) )
        endv = int( np.mean( Att1[i] ) + np.std( Att1[i] ) )
        a = np.linspace( 100 , 161 , 62 )
        b = norm.cdf( a+1 , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) ) - norm.cdf( a , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) )
        plt.plot( a , b*len(Att1[i]) , color = 'red' , linewidth = 3 , label = 'normal distribution' )  

    else:
        a = np.linspace( 50 , 81 , 32 )
        b = norm.cdf( a+1 , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) ) - norm.cdf( a , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) )
        plt.plot( a , b*len(Att1[i]) , color = 'red' , linewidth = 3 , label = 'normal distribution' )
        
        
    
    plt.legend( loc = 'upper left' )    
    plt.show()
# Out:
# SBP  :
# max =  200.0
# min =  80.0
# mean =  130.99574287528492
# std =  21.773316237879676
# DBP  :
# max =  100.0
# min =  50.0
# mean =  65.96708697421127
# std =  10.099018148339777

# %%
for i in M:
    plt.bar( x[i] , y[i] , width = 1 , color = 'blue' , edgecolor = 'white' , lw = 0.2 )#,label = 'Mean = '  + str( np.round( np.mean(Att[i]) , 2 ) )+ '\n' + 'Standard of Deviation = ' + str( np.round( np.std(Att[i]) , 2 ) ) + '\n' + 'Max = ' + str(np.around( np.max( Att[i] ) , 2 ) ) + '\n' + 'Min = ' + str(np.around( np.min( Att[i] ) , 2 ) )  )
    if i == 'DBP':
        plt.xticks( x[i][0::10] )
    else:
        plt.xticks( x[i][0::20] )
        
    print( i , ' :' )
    print( 'max = ' , np.max( Att1[i] ) )
    print( 'min = ' , np.min( Att1[i] ) )
    print( 'mean = ' , np.mean( Att1[i] ) )
    print( 'std = ' , np.std( Att1[i] ) )
    
    plt.ylabel( 'Number of records' , color = 'black' )
    if i == 'SBP':
        plt.xlabel( 'Systolic Blood Pressure (mmHg)' , color = 'black' )
    else:
        plt.xlabel( 'Diatolic Blood Pressure (mmHg)' , color = 'black' )

    if i == 'SBP':
        plt.ylim( (0 , 70000) )
    else:
        plt.ylim( 0 , 150000 )
    
    if i == 'SBP':
        startv = int( np.mean( Att1[i] ) - np.std( Att1[i] ) )
        endv = int( np.mean( Att1[i] ) + np.std( Att1[i] ) )
        a = np.linspace( 100 , 161 , 62 )
        b = norm.cdf( a+1 , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) ) - norm.cdf( a , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) )
        plt.plot( a , b*len(Att1[i]) , color = 'red' , linewidth = 3 , label = 'normal distribution' )  

    else:
        a = np.linspace( 50 , 81 , 32 )
        b = norm.cdf( a+1 , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) ) - norm.cdf( a , loc = np.mean( Att1[i] ) , scale = np.std( Att1[i] ) )
        plt.plot( a , b*len(Att1[i]) , color = 'red' , linewidth = 3 , label = 'normal distribution' )
        
        
    
    plt.legend( loc = 'upper left' )    
    plt.show()
# Out:
# SBP  :
# max =  200.0
# min =  80.0
# mean =  130.99574287528492
# std =  21.773316237879676
# DBP  :
# max =  100.0
# min =  50.0
# mean =  65.96708697421127
# std =  10.099018148339777

# %%
ATT = {}
ATT['r'] = []
ATT['f'] = []
for i in L:
    if i == 'PIR' or i == 'RAAD' or i == 'dRAAD' or i == 'sdRAAD' or i == 'ni':
        continue
    else:
        a = np.linspace( -3 , 3 , 61)
        b = norm.cdf(a+0.1)-norm.cdf(a)
        c = pd.Series(index=a, dtype=float).fillna(0)
        for xi, yi, in zip(x[i],y[i]/np.sum(y[i])):
            if xi in c.index:
                c[xi] = yi
        ATT['r'].append( np.mean( np.abs( b-c ) ) )
        ATT['f'].append( i )
ATT['r'] = np.array( ATT['r'] )

# %%
for i in range( len(ATT['r']) ):
    for j in range( i+1 , len(ATT['r']) , 1 ):
        if ATT['r'][i] > ATT['r'][j]:
            t = ATT['r'][i]
            ATT['r'][i] = ATT['r'][j]
            ATT['r'][j] = t
            t = ATT['f'][i]
            ATT['f'][i] = ATT['f'][j]
            ATT['f'][j] = t
counter = 0
for i in range( len(ATT['r']) ):
    if i == 32:
        print( 'counter = ' , counter )
        print( '-----------------------------------' )
    counter = counter + 1
    print( ATT['f'][i] , ': ' , ATT['r'][i] )
# Out:
# dDA :  0.0122865673465382
# NI :  0.012303321492655507
# DA :  0.012327677430166564
# dAA :  0.012554609812700688
# PI :  0.012615566519011436
# sdDA :  0.01264940449941639
# AI1 :  0.01274883016489462
# AS :  0.012769872429417737
# AI :  0.012776237288860131
# hr :  0.0128115720576161
# RSC :  0.012860231301866617
# dVI :  0.012960338557748209
# sdDS :  0.012987948759984052
# sdAA :  0.012988983980980659
# sdVI :  0.012992765370616634
# sdAID :  0.013052733961933528
# sdPI :  0.0130551618883111
# dRIPV :  0.013057997938749353
# Slope_a :  0.013087989885724077
# sdDID :  0.013100582447186811
# dAID :  0.013110274515131144
# dPI :  0.01313900497726572
# dDID :  0.013220668420511282
# S4 :  0.013235204384249253
# AID :  0.013241260880778207
# S3 :  0.013337541496267886
# sdRIPV :  0.013503764464669643
# AA :  0.013807320809228802
# sdAS :  0.014052564634453188
# DS :  0.014055100491763596
# RSD :  0.01405922392944904
# S2 :  0.014116720097731931
# counter =  32
# ...
